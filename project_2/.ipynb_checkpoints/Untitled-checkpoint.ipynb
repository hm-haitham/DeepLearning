# %% [markdown]
# # Project 2

# %% [markdown]
# The framework should import only torch.empty, and use no pre-existing neural-network python toolbox. Your code should work with autograd globally off, which can be achieved with torch . set˙grad˙enabled ( False )

# %%
import math
import torch 
import matplotlib.pyplot as plt
torch.set_grad_enabled(False)

# %% [markdown]
# ### Build the data

# %% [markdown]
# Generates a training and a test set of 1, 000 points sampled uniformly in [0, 1]², each with a label 0 if outside the disk centered at (0.5, 0.5) of radius 1/sqrt(2π), and 1 inside.

# %%
def build_data(n):
       
    x = torch.empty(n, 2) #(n,2)
    x = x.uniform_(0, 1)
    
    x_centered = x - 0.5
    norm_squared = x_centered.pow(2).sum(dim=1)  #(n,)
    
    r_squared = 1/ (2*math.pi)
    
    y = norm_squared.sub(r_squared).sign().add(1).div(2)
    return x, y

# %%
X_train, y_train = build_data(1000)  #(1000,2) , #(1000)
X_test, y_test = build_data(1000)  #(1000,2) , #(1000)

# %%
x = X_train[:,0]
y = X_train[:,1]
colors = { 1.0 : 'g', 0 : 'y'}

# %%
c = [ colors[label] for label in y_train.numpy()]

# %%
def one_hot_encoding(target):
    encoded = torch.empty(target.shape[0], 2)
    for i in range(target.shape[0]): 
        if(target[i]):
            encoded[i,0] = 0
            encoded[i,1] = target[i]
        else : 
            encoded[i,0] = 1
            encoded[i,1] = target[i]
    return encoded

# %%
encoded_y_train = one_hot_encoding(y_train)
encoded_y_test = one_hot_encoding(y_test)

# %% [markdown]
# ### Visualize the data

# %%
import matplotlib.pyplot as plt  # This is python's popular plotting library.

plt.figure(figsize=(7,7))
plt.scatter(x, y, c = c)
plt.title('Train set')
plt.show()

# %% [markdown]
# ### Build the network

# %%
from linear import Linear
from sequential import Sequential

from activation_function.tanh import Tanh
from activation_function.sigmoid import Sigmoid
from activation_function.relu import ReLU
from activation_function.leakyReLu import LeakyReLU

from optimizer.sgd import SGD
from optimizer.momentum_sgd import MomentumSGDOptimizer

from loss.mse import MSELoss
from loss.cross import CrossEntropyLoss

# %%
def predict(model, X_test, y_test, mini_batch_size = 1):
    
    criterion = MSELoss(model)
    
    number_batches =  X_train.size(0) // mini_batch_size

    #one hot encoding 
    encoded_y_test = one_hot_encoding(y_test)
    
    pred = []
    total_loss = 0
    total_acc = 0
    
    for index in range(0, X_test.size(0), mini_batch_size):
        X_test_batched = X_test[index:(index+mini_batch_size)]
            
        y_test_batched = y_test[index:(index+mini_batch_size)]
        y_test_encoded_batched = encoded_y_test[index:(index+mini_batch_size)]
        
        #forward pass
        output = model.forward(X_test_batched)
        
        loss = criterion.forward(output, y_test_encoded_batched)
        total_loss += loss.item() 
        
        batch_acc =  (output.max(1)[1].float() == y_test_batched).sum()
        total_acc += batch_acc.item()
        pred.append(output)
        
    total_loss = total_loss / number_batches
    
    print('Obtain on the test set an average loss of {0} and an accuracy of {1}'.format(total_loss,total_acc))
    
    return pred, total_loss,total_acc

# %%
def train_model(model, X_train, y_train, X_test, y_test, epochs, mini_batch_size , 
                lr = 0.01, momentum = 0.9):
    
    total_loss = []
    total_acc = []
    
    test_pred = [] 
    test_loss = []
    test_acc = []
    
    criterion = MSELoss(model)
    optimizer = MomentumSGDOptimizer(model, lr, momentum)
    
    #one hot encoding 
    encoded_y_train = one_hot_encoding(y_train)
    
    number_batches =  X_train.size(0) // mini_batch_size
    
    for epoch in range(epochs):
        
        loss_epoch = 0
        acc_epoch = 0
        pred = []
        
        for index in range(0, X_train.size(0), mini_batch_size):
            X_train_batched = X_train[index:(index+mini_batch_size)]
            
            y_train_batched = y_train[index:(index+mini_batch_size)]
            y_train_encoded_batched = encoded_y_train[index:(index+mini_batch_size)]
            
            #forward pass
            output = model.forward(X_train_batched)
            loss = criterion.forward(output, y_train_encoded_batched)
            loss_epoch += loss.item() 
            
            #batch_acc = ((output.round() == y_train_encoded_batched_).sum(1) == 2).sum(0)
            batch_acc =  (output.max(1)[1].float() == y_train_batched).sum()
            acc_epoch += batch_acc
            
            #backward pass and update parameters gradient
            criterion.backward()  
            #update parameters
            optimizer.step()
        
        total_acc.append(acc_epoch)
        total_loss.append(loss_epoch / number_batches)
        
        #compute the predictions on the test set for this epoch model
        pred_epoch, test_loss_epoch, test_acc_epoch = predict(model, X_test, y_test)
        test_pred.append(pred_epoch)
        test_loss.append(test_loss_epoch)
        test_acc.append(test_acc_epoch)

    return model, total_loss, total_acc, test_pred, test_loss, test_acc

# %%
input_units = 2
hidden_units = 25
output_units = 2

model = Sequential(
            Linear(input_units, hidden_units),
            LeakyReLU(),
            Linear(hidden_units, hidden_units),
            LeakyReLU(),
            Linear(hidden_units, hidden_units),
            LeakyReLU(),
            Linear(hidden_units, output_units),
            Sigmoid()
)

# %%
epochs = 50
mini_batch_size = 5
model, total_loss, total_acc, test_pred, test_loss, test_acc = train_model(model, X_train, y_train, X_test, y_test,
                                                                           epochs, mini_batch_size , lr = 0.01)
# Out:
# Obtain on the test set an average loss of 0.49547771498560905 and an accuracy of 497
# Obtain on the test set an average loss of 0.46931765469908715 and an accuracy of 610
# Obtain on the test set an average loss of 0.40464420748502017 and an accuracy of 733
# Obtain on the test set an average loss of 0.28371650078799576 and an accuracy of 815
# Obtain on the test set an average loss of 0.22491326894995292 and an accuracy of 835
# Obtain on the test set an average loss of 0.18129505756356956 and an accuracy of 863
# Obtain on the test set an average loss of 0.18442897086329543 and an accuracy of 858
# Obtain on the test set an average loss of 0.15438957963821412 and an accuracy of 884
# Obtain on the test set an average loss of 0.17317383035335948 and an accuracy of 878
# Obtain on the test set an average loss of 0.15601203971577948 and an accuracy of 887
# Obtain on the test set an average loss of 0.15201847198789975 and an accuracy of 888
# Obtain on the test set an average loss of 0.18064727943832934 and an accuracy of 869
# Obtain on the test set an average loss of 0.15767344892787039 and an accuracy of 887
# Obtain on the test set an average loss of 0.18924328581593808 and an accuracy of 869
# Obtain on the test set an average loss of 0.1676919760520758 and an accuracy of 878
# Obtain on the test set an average loss of 0.19203331075795108 and an accuracy of 870
# Obtain on the test set an average loss of 0.1445805324870786 and an accuracy of 899
# Obtain on the test set an average loss of 0.1540924864319064 and an accuracy of 890
# Obtain on the test set an average loss of 0.18099016927131661 and an accuracy of 872
# Obtain on the test set an average loss of 0.17071209314775077 and an accuracy of 887

# %%
plt.plot(loss_epoch)
plt.title('Average loss per epoch')
plt.show()

# %%
plt.plot(total_acc)
plt.title('Accuracy on train set per epoch')
plt.show()

# %%
plt.plot(test_acc)
plt.title('Accuracy on test set per epoch')
plt.show()

# %% [markdown]
# ## Visualize the decision boundary

# %%
X_viz, y_viz = build_data(10000)

# %%
x_viz = X_viz[:,0]
y_viz= X_viz[:,1]

# %%
c_viz = [ colors[label] for label in y_train.numpy()]

# %% [markdown]
# ## Pytorch

# %%
import torch.nn as nn

torch.set_grad_enabled(True)

model_torch = nn.Sequential(
            nn.Linear(input_units, hidden_units),
            nn.ReLU(),
            nn.Linear(hidden_units, hidden_units),
            nn.ReLU(),
            nn.Linear(hidden_units, hidden_units),
            nn.ReLU(),
            nn.Linear(hidden_units, output_units),
            nn.Sigmoid()
)

# %%
def train_model(model, train_input, train_target, mini_batch_size):
    criterion = nn.MSELoss()
    eta = 1e-1

    for e in range(25):
        sum_loss = 0
        for b in range(0, train_input.size(0), mini_batch_size):
            output = model(train_input.narrow(0, b, mini_batch_size))
            loss = criterion(output, train_target.narrow(0, b, mini_batch_size))
            model.zero_grad()
            loss.backward()
            sum_loss = sum_loss + loss.item()
            with torch.no_grad():
                for p in model.parameters():
                    p -= eta * p.grad
        print(e, sum_loss)
    
    return model

def compute_nb_errors(model, input, target, mini_batch_size):
    nb_errors = 0

    for b in range(0, input.size(0), mini_batch_size):
        output = model(input.narrow(0, b, mini_batch_size))
        _, predicted_classes = output.max(1)
        for k in range(mini_batch_size):
            if target[b + k, predicted_classes[k]] <= 0:
                nb_errors = nb_errors + 1

    return nb_errors

# %%
#one hot encoding 
encoded_y_train = one_hot_encoding(y_train)

# %%
train_model(model_torch, X_train, encoded_y_train, 5)

# %%
compute_nb_errors(model, input, target, mini_batch_size)

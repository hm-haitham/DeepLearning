# %% [markdown]
# # Visualization

# %%
# %load_ext autoreload
# %autoreload 2 

import helpers
import config

import torch
import torch.nn as nn
import numpy as np

from models.BasicNet import BasicNet
from train import train_basic
from predict import predict_basic

from models.CNN import CNN
from models.FCN import FCN 

from models.SiameseNet import SiameseNet
from train import train_siamese
from predict import predict_siamese

import torch.utils.data as data
import matplotlib.pyplot as plt
from datasets import PairDataset
from torchsummary import summary

# %%
rounds = 10

# %% [markdown]
# ## Load data

# %%
pairs = helpers.generate_pair_sets(config.NB_SAMPLES)

train_dataset = PairDataset(pairs[0], pairs[1], pairs[2])
train_dataloader = data.DataLoader(dataset=train_dataset, batch_size= config.TRAIN_BATCH_SIZE, shuffle=True)

test_dataset = PairDataset(pairs[3], pairs[4], pairs[5])
test_dataloader = data.DataLoader(dataset=test_dataset, batch_size=config.TEST_BATCH_SIZE, shuffle=True)

# %% [markdown]
# ## Plot

# %% [markdown]
# ### Basic Net

# %%
summary(BasicNet(), (1 ,2, 14, 14))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 512]         201,216
#             Linear-2                    [-1, 1]             513
# ================================================================
# Total params: 201,729
# Trainable params: 201,729
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.77
# Estimated Total Size (MB): 0.77
# ----------------------------------------------------------------

# %%
round_results = [] #3D
    
for i in range(rounds):
    print("Round {0}".format(i))

    results = [] #training_losses, training_acc, test_losses, test_acc
    
    model = BasicNet()
    
    training_losses, training_acc, test_losses, test_acc = train_basic(model, train_dataloader, test_dataloader, epochs = config.EPOCHS,  learning_rate= 0.00001)

    results.append([training_losses, training_acc, test_losses, test_acc])
              
    print("With {0} batch size and {1} epochs and {2} learning rate we get :".format(config.TRAIN_BATCH_SIZE, config.EPOCHS, config.LEARNING_RATE))
    
    final_test_loss, final_test_loss_acc = predict_basic(model, test_dataloader)
    print("On the test set we obtain a loss of {:.2f} and an accuracy of {:.2f}".format(final_test_loss,final_test_loss_acc))
      
    round_results.append(results)

# %%
means = np.array(round_results).mean(axis= 0).reshape((4,20))
std  = np.array(round_results).std(axis = 0).reshape((4,20))

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize= (14,8))

ax1.plot(means[0], color = 'r', label = 'training loss')
ax1.plot(means[2], color = 'b',  linestyle='dashed', label = 'test loss')
        
ax1.fill_between(range(len(means[0])), means[0] - std[0], means[0] + std[0], alpha = 0.2, color = 'r')
ax1.fill_between(range(len(means[2])), means[2] - std[2], means[2] + std[2], alpha = 0.2, color = 'b')

ax2.plot(means[1], color = 'r', label = 'training accuracy')
ax2.plot(means[3], color = 'b', linestyle='dashed', label = 'test accuracy')

ax2.fill_between(range(len(means[1])), means[1]- std[1], means[1]+ std[1], alpha = 0.2, color = 'r')
ax2.fill_between(range(len(means[3])), means[3]- std[3], means[3]+ std[3], alpha = 0.2, color = 'b')

ax1.set_title('Training Binary Cross Entropy Loss')
ax1.set_xlabel("Epochs")
ax1.set_ylabel("BCE")

ax2.set_title('Training accuracy}')
ax2.set_xlabel("Epochs")
ax2.set_ylabel("Accuracy")

ax1.legend(loc = 'upper right')
ax2.legend(loc = 'lower right')
plt.subplots_adjust(left=0.07, right=0.93, wspace=0.25, hspace=0.35)
plt.show()

# %% [markdown]
# ### Siamese Net

# %% [markdown]
# We want to assess the difference w/o aux loss and weight sharing for each subnet configuration

# %%
configuration = [
    (weight_sharing, aux_loss)
    
    for weight_sharing in [False,True]
    for aux_loss in [False,True]
]
configuration
# Out:
# [(False, False), (False, True), (True, False), (True, True)]

# %%
def compute_results_fcn(subnet_type, nb_hidden_layers = config.FCN_NB_HIDDEN, 
                    hidden_layer = config.FCN_HIDDEN_LAYER,
                    nb_hidden_layers_out = config.SIAMESE_NET_NB_HIDDEN,
                    hidden_layer_out = config.SIAMESE_NET_HIDDEN_LAYER,
                    alpha = config.ALPHA): 

    round_results = []

    for i in range(rounds):
        results = [] #training_losses, training_acc, test_losses, test_acc
        
        for weight_sharing, aux_loss in configuration:
            subnet1 = FCN(nb_hidden_layers, hidden_layer)
            subnet2 = FCN(nb_hidden_layers, hidden_layer)
            
            print('Model for weight_sharing = {0} and aux loss = {1} on round {2} with subnet {3}'.format(weight_sharing, aux_loss, 
                                                                                                          i,subnet_type))
            
            if(weight_sharing):
                model = SiameseNet(subnet1, None, nb_hidden_layers_out, hidden_layer_out)
            else: 
                model = SiameseNet(subnet1, subnet2, nb_hidden_layers_out, hidden_layer_out)
            
            training_losses, training_acc, _, _, test_losses, test_acc, _, _ = train_siamese(
                    model = model, dataloader = train_dataloader, test_dataloader = test_dataloader, aux_loss = aux_loss, alpha = alpha)        
            
            final_test_loss, final_test_loss_acc, _, _ = predict_siamese(model, test_dataloader, aux_loss, alpha)
            print("In epoch 20, on the test set we obtain a loss of {:.2f} and an accuracy of {:.2f}".format(final_test_loss,final_test_loss_acc))
            results.append([training_losses, training_acc, test_losses, test_acc])

        round_results.append(results)

    return round_results

# %%
def compute_results_cnn(subnet_type, nb_hidden_layers = config.CNN_NB_HIDDEN, 
                    base_channel_size = config.CNN_BASE_CHANNEL_SIZE, 
                    hidden_layer = config.CNN_HIDDEN_LAYER,
                    kernel_size = config.CNN_KERNEL_SIZE,
                    nb_hidden_layers_out = config.SIAMESE_NET_NB_HIDDEN,
                    hidden_layer_out = config.SIAMESE_NET_HIDDEN_LAYER,
                    alpha = config.ALPHA): 

    round_results = []

    for i in range(rounds):
        results = [] #training_losses, training_acc, test_losses, test_acc
        
        for weight_sharing, aux_loss in configuration:
            subnet1 = CNN(nb_hidden_layers, base_channel_size, hidden_layer, kernel_size)
            subnet2 = CNN(nb_hidden_layers, base_channel_size, hidden_layer, kernel_size)
            
            print('Model for weight_sharing = {0} and aux loss = {1} on round {2} with subnet {3}'.format(weight_sharing, aux_loss, 
                                                                                                          i,subnet_type))
            
            if(weight_sharing):
                model = SiameseNet(subnet1, None, nb_hidden_layers_out, hidden_layer_out)
            else: 
                model = SiameseNet(subnet1, subnet2, nb_hidden_layers_out, hidden_layer_out)
            
            training_losses, training_acc, _, _, test_losses, test_acc, _, _ = train_siamese(
                    model = model, dataloader = train_dataloader, test_dataloader = test_dataloader, aux_loss = aux_loss, alpha = alpha)        
            
            final_test_loss, final_test_loss_acc, _, _ = predict_siamese(model, test_dataloader, aux_loss, alpha)
            print("In epoch 20, on the test set we obtain a loss of {:.2f} and an accuracy of {:.2f}".format(final_test_loss,final_test_loss_acc))
            results.append([training_losses, training_acc, test_losses, test_acc])

        round_results.append(results)

    return round_results

# %%
def plots_results(round_results, subnet_type):
    
    colors = ['b', 'g', 'r', 'm']

    fig, (ax1, ax2) = plt.subplots(1, 2,figsize= (14,8))

    means = np.array(round_results).mean(axis= 0)
    std  = np.array(round_results).std(axis = 0)
    dict_word = {False :'without', True : 'with'}
    for i, (r,s,p) in enumerate( zip(means,std,configuration) ):

        ax1.plot(r[0], color = colors[i], label = 'training loss {0} WS and {1} AL'.format(dict_word[p[0]], dict_word[p[1]]))
        ax1.plot(r[2], color = colors[i],  linestyle='dashed', label = 'test loss {0} WS and {1} AL'.format(dict_word[p[0]], dict_word[p[1]]))

        ax1.fill_between(range(len(r[0])), r[0] - s[0], r[0]+ s[0], alpha = 0.2, color = colors[i])
        ax1.fill_between(range(len(r[2])), r[2]- s[2], r[2]+ s[2], alpha = 0.2, color = colors[i])

        ax2.plot(r[1], color = colors[i], label = 'training accuracy {0} WS and {1} AL'.format(dict_word[p[0]], dict_word[p[1]]))
        ax2.plot(r[3], color = colors[i], linestyle='dashed', label = 'test accuracy {0} WS and {1} AL'.format(dict_word[p[0]], dict_word[p[1]]))

        ax2.fill_between(range(len(r[1])), r[1]- s[1], r[1]+ s[1], alpha = 0.2, color = colors[i])
        ax2.fill_between(range(len(r[3])), r[3]- s[3], r[3]+ s[3], alpha = 0.2, color = colors[i])

    ax1.set_title('Training Binary Cross Entropy with {0} subnets'.format(subnet_type))
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("BCE")

    ax2.set_title('Training accuracy with {0} subnets'.format(subnet_type))
    ax2.set_xlabel("Epochs")
    ax2.set_ylabel("Accuracy")

    ax1.legend(loc = 'upper right')
    ax2.legend(loc = 'lower right')
    plt.subplots_adjust(left=0.07, right=0.93, wspace=0.25, hspace=0.35)
    plt.show()

# %% [markdown]
# #### Subnets : FCN

# %%
FCN()
# Out:
# FCN(
#   (hiddens): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=196, out_features=64, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Dropout(p=0.2)
#     )
#   )
#   (output): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
round_results_FCN = compute_results_fcn('FCN')
# Out:
# Model for weight_sharing = False and aux loss = False on round 0 with subnet FCN
# At epoch 1 the training loss is 0.7393079074472189
# At epoch 1 the training accuracy is 0.652
# epoch 1/20
# The test loss is 0.5059962868690491
# The test accuracy is 0.76
# At epoch 2 the training loss is 0.5168883879110218
# At epoch 2 the training accuracy is 0.758
# epoch 2/20
# The test loss is 0.4662361741065979
# The test accuracy is 0.757
# At epoch 3 the training loss is 0.4196923411078751
# At epoch 3 the training accuracy is 0.808
# epoch 3/20
# The test loss is 0.4872288107872009
# The test accuracy is 0.764
# At epoch 4 the training loss is 0.3800339947408065
# At epoch 4 the training accuracy is 0.822
# epoch 4/20
# The test loss is 0.5599991679191589
# The test accuracy is 0.749
# At epoch 5 the training loss is 0.3116641235677525
# At epoch 5 the training accuracy is 0.853
# epoch 5/20
# The test loss is 0.48571696877479553
# The test accuracy is 0.805
# At epoch 6 the training loss is 0.27208087985171003
# At epoch 6 the training accuracy is 0.891
# epoch 6/20
# The test loss is 0.5396211743354797
# The test accuracy is 0.775
# At epoch 7 the training loss is 0.23157782257301732
# At epoch 7 the training accuracy is 0.9
# epoch 7/20
# The test loss is 0.4577378034591675
# The test accuracy is 0.799
# At epoch 8 the training loss is 0.19322210406011436
# At epoch 8 the training accuracy is 0.923
# epoch 8/20
# The test loss is 0.5136303305625916
# The test accuracy is 0.815
# At epoch 9 the training loss is 0.16766448840731754
# At epoch 9 the training accuracy is 0.931
# epoch 9/20
# The test loss is 0.508830726146698
# The test accuracy is 0.814
# At epoch 10 the training loss is 0.14362303782894742
# At epoch 10 the training accuracy is 0.944
# epoch 10/20
# The test loss is 0.5561912655830383
# The test accuracy is 0.802
# At epoch 11 the training loss is 0.11494453678598802
# At epoch 11 the training accuracy is 0.958
# epoch 11/20
# The test loss is 0.6242872476577759
# The test accuracy is 0.807
# At epoch 12 the training loss is 0.11139780491910642
# At epoch 12 the training accuracy is 0.964
# epoch 12/20
# The test loss is 0.6481842398643494
# The test accuracy is 0.804
# At epoch 13 the training loss is 0.0753950394122512
# At epoch 13 the training accuracy is 0.968
# epoch 13/20
# The test loss is 0.7460719347000122
# The test accuracy is 0.807
# At epoch 14 the training loss is 0.05279221262037936
# At epoch 14 the training accuracy is 0.982
# epoch 14/20
# The test loss is 0.8577167391777039
# The test accuracy is 0.804
# At epoch 15 the training loss is 0.05487721594570303
# At epoch 15 the training accuracy is 0.977
# epoch 15/20
# The test loss is 0.8511042594909668
# The test accuracy is 0.825
# At epoch 16 the training loss is 0.07666715079022055
# At epoch 16 the training accuracy is 0.977
# epoch 16/20
# The test loss is 0.8184232115745544
# The test accuracy is 0.811
# At epoch 17 the training loss is 0.041064488505658116
# At epoch 17 the training accuracy is 0.984
# epoch 17/20
# The test loss is 0.8129358887672424
# The test accuracy is 0.817
# At epoch 18 the training loss is 0.035936956262240596
# At epoch 18 the training accuracy is 0.985
# epoch 18/20
# The test loss is 0.9060930013656616
# The test accuracy is 0.824
# At epoch 19 the training loss is 0.0362359039321916
# At epoch 19 the training accuracy is 0.986
# epoch 19/20
# The test loss is 0.9895164966583252
# The test accuracy is 0.814
# At epoch 20 the training loss is 0.030592727221664083
# At epoch 20 the training accuracy is 0.991
# epoch 20/20
# The test loss is 1.01352059841156
# The test accuracy is 0.809
# The test loss is 1.0135208368301392
# The test accuracy is 0.809
# In epoch 20, on the test set we obtain a loss of 1.01 and an accuracy of 0.81
# Model for weight_sharing = False and aux loss = True on round 0 with subnet FCN
# At epoch 1 the training loss is 2.849269929677248
# At epoch 1 the training accuracy is 0.622
# epoch 1/20
# The test loss is 0.8579180240631104
# The test accuracy is 0.751
# At epoch 2 the training loss is 0.7753961566835642
# At epoch 2 the training accuracy is 0.759
# epoch 2/20
# The test loss is 0.6749677658081055
# The test accuracy is 0.781
# At epoch 3 the training loss is 0.522618217151612
# At epoch 3 the training accuracy is 0.803
# epoch 3/20
# The test loss is 0.5962634682655334
# The test accuracy is 0.79
# At epoch 4 the training loss is 0.4222856439463794
# At epoch 4 the training accuracy is 0.832
# epoch 4/20
# The test loss is 0.5738400220870972
# The test accuracy is 0.814
# At epoch 5 the training loss is 0.39838533094152806
# At epoch 5 the training accuracy is 0.839
# epoch 5/20
# The test loss is 0.5796550512313843
# The test accuracy is 0.808
# At epoch 6 the training loss is 0.315806988524273
# At epoch 6 the training accuracy is 0.865
# epoch 6/20
# The test loss is 0.5628300905227661
# The test accuracy is 0.834
# At epoch 7 the training loss is 0.2684613176016137
# At epoch 7 the training accuracy is 0.885
# epoch 7/20
# The test loss is 0.5404093861579895
# The test accuracy is 0.823
# At epoch 8 the training loss is 0.2382139508612454
# At epoch 8 the training accuracy is 0.898
# epoch 8/20
# The test loss is 0.5692025423049927
# The test accuracy is 0.833
# At epoch 9 the training loss is 0.23602837185375392
# At epoch 9 the training accuracy is 0.902
# epoch 9/20
# The test loss is 0.5448992252349854
# The test accuracy is 0.846
# At epoch 10 the training loss is 0.20320786151802167
# At epoch 10 the training accuracy is 0.912
# epoch 10/20
# The test loss is 0.5563160181045532
# The test accuracy is 0.847
# At epoch 11 the training loss is 0.1799475451244507
# At epoch 11 the training accuracy is 0.928
# epoch 11/20
# The test loss is 0.5658320188522339
# The test accuracy is 0.848
# At epoch 12 the training loss is 0.15306810181529726
# At epoch 12 the training accuracy is 0.934
# epoch 12/20
# The test loss is 0.5690811276435852
# The test accuracy is 0.843
# At epoch 13 the training loss is 0.15490128770819866
# At epoch 13 the training accuracy is 0.929
# epoch 13/20
# The test loss is 0.5730379223823547
# The test accuracy is 0.846
# At epoch 14 the training loss is 0.13629371830204037
# At epoch 14 the training accuracy is 0.947
# epoch 14/20
# The test loss is 0.5927680730819702
# The test accuracy is 0.846
# At epoch 15 the training loss is 0.12314014798146672
# At epoch 15 the training accuracy is 0.947
# epoch 15/20
# The test loss is 0.6042731404304504
# The test accuracy is 0.848
# At epoch 16 the training loss is 0.11776350729669502
# At epoch 16 the training accuracy is 0.954
# epoch 16/20
# The test loss is 0.5891211032867432
# The test accuracy is 0.851
# At epoch 17 the training loss is 0.1276672081043944
# At epoch 17 the training accuracy is 0.952
# epoch 17/20
# The test loss is 0.5771880745887756
# The test accuracy is 0.859
# At epoch 18 the training loss is 0.10977721901683253
# At epoch 18 the training accuracy is 0.951
# epoch 18/20
# The test loss is 0.5562544465065002
# The test accuracy is 0.87
# At epoch 19 the training loss is 0.10793964177486487
# At epoch 19 the training accuracy is 0.958
# epoch 19/20
# The test loss is 0.5701496601104736
# The test accuracy is 0.851
# At epoch 20 the training loss is 0.0976855142157001
# At epoch 20 the training accuracy is 0.965
# epoch 20/20
# The test loss is 0.5887241959571838
# The test accuracy is 0.853
# The test loss is 0.5887241363525391
# The test accuracy is 0.853
# In epoch 20, on the test set we obtain a loss of 0.59 and an accuracy of 0.85
# Model for weight_sharing = True and aux loss = False on round 0 with subnet FCN
# At epoch 1 the training loss is 0.7441676106676459
# At epoch 1 the training accuracy is 0.637
# epoch 1/20
# The test loss is 0.5013890266418457
# The test accuracy is 0.749
# At epoch 2 the training loss is 0.48665905515663327
# At epoch 2 the training accuracy is 0.773
# epoch 2/20
# The test loss is 0.4236759543418884
# The test accuracy is 0.804
# At epoch 3 the training loss is 0.39244862656109036
# At epoch 3 the training accuracy is 0.826
# epoch 3/20
# The test loss is 0.4116377830505371
# The test accuracy is 0.81
# At epoch 4 the training loss is 0.3259130920458119
# At epoch 4 the training accuracy is 0.859
# epoch 4/20
# The test loss is 0.41060689091682434
# The test accuracy is 0.824
# At epoch 5 the training loss is 0.29567329871002584
# At epoch 5 the training accuracy is 0.879
# epoch 5/20
# The test loss is 0.40558183193206787
# The test accuracy is 0.83
# At epoch 6 the training loss is 0.23704889287706465
# At epoch 6 the training accuracy is 0.903
# epoch 6/20
# The test loss is 0.40741145610809326
# The test accuracy is 0.844
# At epoch 7 the training loss is 0.20834663758869282
# At epoch 7 the training accuracy is 0.918
# epoch 7/20
# The test loss is 0.452541708946228
# The test accuracy is 0.832
# At epoch 8 the training loss is 0.18309853260609088
# At epoch 8 the training accuracy is 0.935
# epoch 8/20
# The test loss is 0.4670111835002899
# The test accuracy is 0.839
# At epoch 9 the training loss is 0.16516209988991248
# At epoch 9 the training accuracy is 0.937
# epoch 9/20
# The test loss is 0.5160320401191711
# The test accuracy is 0.846
# At epoch 10 the training loss is 0.13078398645066044
# At epoch 10 the training accuracy is 0.951
# epoch 10/20
# The test loss is 0.5381818413734436
# The test accuracy is 0.826
# At epoch 11 the training loss is 0.12310212419010441
# At epoch 11 the training accuracy is 0.958
# epoch 11/20
# The test loss is 0.6532536745071411
# The test accuracy is 0.828
# At epoch 12 the training loss is 0.11904867043194826
# At epoch 12 the training accuracy is 0.95
# epoch 12/20
# The test loss is 0.5515719652175903
# The test accuracy is 0.841
# At epoch 13 the training loss is 0.09087398931572807
# At epoch 13 the training accuracy is 0.962
# epoch 13/20
# The test loss is 0.664216935634613
# The test accuracy is 0.839
# At epoch 14 the training loss is 0.07976549153522683
# At epoch 14 the training accuracy is 0.973
# epoch 14/20
# The test loss is 0.6286215782165527
# The test accuracy is 0.837
# At epoch 15 the training loss is 0.04603874959814903
# At epoch 15 the training accuracy is 0.988
# epoch 15/20
# The test loss is 0.736416220664978
# The test accuracy is 0.845
# At epoch 16 the training loss is 0.057778535037290905
# At epoch 16 the training accuracy is 0.982
# epoch 16/20
# The test loss is 0.7499622702598572
# The test accuracy is 0.839
# At epoch 17 the training loss is 0.049092931126508574
# At epoch 17 the training accuracy is 0.984
# epoch 17/20
# The test loss is 0.7599316835403442
# The test accuracy is 0.834
# At epoch 18 the training loss is 0.0443371251945257
# At epoch 18 the training accuracy is 0.98
# epoch 18/20
# The test loss is 0.8285325765609741
# The test accuracy is 0.824
# At epoch 19 the training loss is 0.05322148310053649
# At epoch 19 the training accuracy is 0.983
# epoch 19/20
# The test loss is 0.8525922298431396
# The test accuracy is 0.824
# At epoch 20 the training loss is 0.03894662917578115
# At epoch 20 the training accuracy is 0.984
# epoch 20/20
# The test loss is 0.893790602684021
# The test accuracy is 0.82
# The test loss is 0.8937904834747314
# The test accuracy is 0.82
# In epoch 20, on the test set we obtain a loss of 0.89 and an accuracy of 0.82
# Model for weight_sharing = True and aux loss = True on round 0 with subnet FCN
# At epoch 1 the training loss is 2.6062574052810668
# At epoch 1 the training accuracy is 0.602
# epoch 1/20
# The test loss is 0.7402147650718689
# The test accuracy is 0.736
# At epoch 2 the training loss is 0.7209893000870943
# At epoch 2 the training accuracy is 0.737
# epoch 2/20
# The test loss is 0.6003003120422363
# The test accuracy is 0.771
# At epoch 3 the training loss is 0.5525072565302253
# At epoch 3 the training accuracy is 0.759
# epoch 3/20
# The test loss is 0.527914822101593
# The test accuracy is 0.774
# At epoch 4 the training loss is 0.45942617796361446
# At epoch 4 the training accuracy is 0.79
# epoch 4/20
# The test loss is 0.48126351833343506
# The test accuracy is 0.804
# At epoch 5 the training loss is 0.4100630025565624
# At epoch 5 the training accuracy is 0.814
# epoch 5/20
# The test loss is 0.4496234655380249
# The test accuracy is 0.811
# At epoch 6 the training loss is 0.34027884874492886
# At epoch 6 the training accuracy is 0.854
# epoch 6/20
# The test loss is 0.4471047520637512
# The test accuracy is 0.825
# At epoch 7 the training loss is 0.31326327749760824
# At epoch 7 the training accuracy is 0.853
# epoch 7/20
# The test loss is 0.4329615831375122
# The test accuracy is 0.834
# At epoch 8 the training loss is 0.2797253081249073
# At epoch 8 the training accuracy is 0.848
# epoch 8/20
# The test loss is 0.41493940353393555
# The test accuracy is 0.857
# At epoch 9 the training loss is 0.26165495386347176
# At epoch 9 the training accuracy is 0.885
# epoch 9/20
# The test loss is 0.37137752771377563
# The test accuracy is 0.868
# At epoch 10 the training loss is 0.23910506939981133
# At epoch 10 the training accuracy is 0.909
# epoch 10/20
# The test loss is 0.3751624524593353
# The test accuracy is 0.874
# At epoch 11 the training loss is 0.2048133966093883
# At epoch 11 the training accuracy is 0.914
# epoch 11/20
# The test loss is 0.38540032505989075
# The test accuracy is 0.872
# At epoch 12 the training loss is 0.1959801481757313
# At epoch 12 the training accuracy is 0.926
# epoch 12/20
# The test loss is 0.40110349655151367
# The test accuracy is 0.876
# At epoch 13 the training loss is 0.1901274823327549
# At epoch 13 the training accuracy is 0.912
# epoch 13/20
# The test loss is 0.3815461993217468
# The test accuracy is 0.877
# At epoch 14 the training loss is 0.18356224762857892
# At epoch 14 the training accuracy is 0.932
# epoch 14/20
# The test loss is 0.37666475772857666
# The test accuracy is 0.869
# At epoch 15 the training loss is 0.16272577344439923
# At epoch 15 the training accuracy is 0.94
# epoch 15/20
# The test loss is 0.3789142370223999
# The test accuracy is 0.877
# At epoch 16 the training loss is 0.14065946753718891
# At epoch 16 the training accuracy is 0.95
# epoch 16/20
# The test loss is 0.4046882390975952
# The test accuracy is 0.873
# At epoch 17 the training loss is 0.13325159878178966
# At epoch 17 the training accuracy is 0.949
# epoch 17/20
# The test loss is 0.3911130428314209
# The test accuracy is 0.877
# At epoch 18 the training loss is 0.12830369515751955
# At epoch 18 the training accuracy is 0.956
# epoch 18/20
# The test loss is 0.4034055769443512
# The test accuracy is 0.884
# At epoch 19 the training loss is 0.1251570190046914
# At epoch 19 the training accuracy is 0.955
# epoch 19/20
# The test loss is 0.4114495515823364
# The test accuracy is 0.884
# At epoch 20 the training loss is 0.1083619505155366
# At epoch 20 the training accuracy is 0.957
# epoch 20/20
# The test loss is 0.40398240089416504
# The test accuracy is 0.883
# The test loss is 0.40398240089416504
# The test accuracy is 0.883
# In epoch 20, on the test set we obtain a loss of 0.40 and an accuracy of 0.88
# Model for weight_sharing = False and aux loss = False on round 1 with subnet FCN
# At epoch 1 the training loss is 0.7551096103340388
# At epoch 1 the training accuracy is 0.635
# epoch 1/20
# The test loss is 0.49627605080604553
# The test accuracy is 0.764
# At epoch 2 the training loss is 0.5332327496260405
# At epoch 2 the training accuracy is 0.746
# epoch 2/20
# The test loss is 0.5065914988517761
# The test accuracy is 0.749
# At epoch 3 the training loss is 0.4308292227424681
# At epoch 3 the training accuracy is 0.803
# epoch 3/20
# The test loss is 0.4613003432750702
# The test accuracy is 0.788
# At epoch 4 the training loss is 0.37403084891382604
# At epoch 4 the training accuracy is 0.829
# epoch 4/20
# The test loss is 0.4373522698879242
# The test accuracy is 0.788
# At epoch 5 the training loss is 0.31247221731580793
# At epoch 5 the training accuracy is 0.879
# epoch 5/20
# The test loss is 0.4987691044807434
# The test accuracy is 0.8
# At epoch 6 the training loss is 0.29319237771211193
# At epoch 6 the training accuracy is 0.879
# epoch 6/20
# The test loss is 0.46058475971221924
# The test accuracy is 0.801
# At epoch 7 the training loss is 0.22037796459626408
# At epoch 7 the training accuracy is 0.918
# epoch 7/20
# The test loss is 0.5346754193305969
# The test accuracy is 0.801
# At epoch 8 the training loss is 0.19821931148704608
# At epoch 8 the training accuracy is 0.917
# epoch 8/20
# The test loss is 0.5836597681045532
# The test accuracy is 0.805
# At epoch 9 the training loss is 0.14705399854476128
# At epoch 9 the training accuracy is 0.944
# epoch 9/20
# The test loss is 0.584354817867279
# The test accuracy is 0.815
# At epoch 10 the training loss is 0.12966745561494464
# At epoch 10 the training accuracy is 0.951
# epoch 10/20
# The test loss is 0.7929630279541016
# The test accuracy is 0.796
# At epoch 11 the training loss is 0.12184590045933874
# At epoch 11 the training accuracy is 0.958
# epoch 11/20
# The test loss is 0.6547331809997559
# The test accuracy is 0.812
# At epoch 12 the training loss is 0.08919580913446425
# At epoch 12 the training accuracy is 0.967
# epoch 12/20
# The test loss is 0.7957255244255066
# The test accuracy is 0.809
# At epoch 13 the training loss is 0.08190396968368077
# At epoch 13 the training accuracy is 0.963
# epoch 13/20
# The test loss is 0.7695744633674622
# The test accuracy is 0.812
# At epoch 14 the training loss is 0.05675088315643279
# At epoch 14 the training accuracy is 0.985
# epoch 14/20
# The test loss is 0.8922586441040039
# The test accuracy is 0.813
# At epoch 15 the training loss is 0.04105954046661736
# At epoch 15 the training accuracy is 0.983
# epoch 15/20
# The test loss is 0.9411971569061279
# The test accuracy is 0.815
# At epoch 16 the training loss is 0.05581715396619984
# At epoch 16 the training accuracy is 0.98
# epoch 16/20
# The test loss is 0.9223330020904541
# The test accuracy is 0.821
# At epoch 17 the training loss is 0.03506736697081237
# At epoch 17 the training accuracy is 0.987
# epoch 17/20
# The test loss is 0.9986118674278259
# The test accuracy is 0.807
# At epoch 18 the training loss is 0.032635531198201305
# At epoch 18 the training accuracy is 0.987
# epoch 18/20
# The test loss is 1.0747703313827515
# The test accuracy is 0.808
# At epoch 19 the training loss is 0.03281652387357077
# At epoch 19 the training accuracy is 0.987
# epoch 19/20
# The test loss is 1.0904569625854492
# The test accuracy is 0.813
# At epoch 20 the training loss is 0.04384745171228758
# At epoch 20 the training accuracy is 0.989
# epoch 20/20
# The test loss is 1.0809569358825684
# The test accuracy is 0.807
# The test loss is 1.0809574127197266
# The test accuracy is 0.807
# In epoch 20, on the test set we obtain a loss of 1.08 and an accuracy of 0.81
# Model for weight_sharing = False and aux loss = True on round 1 with subnet FCN
# At epoch 1 the training loss is 3.0569327719509602
# At epoch 1 the training accuracy is 0.616
# epoch 1/20
# The test loss is 0.8974660634994507
# The test accuracy is 0.723
# At epoch 2 the training loss is 0.8039179229736328
# At epoch 2 the training accuracy is 0.742
# epoch 2/20
# The test loss is 0.7119600176811218
# The test accuracy is 0.769
# At epoch 3 the training loss is 0.5874343222752213
# At epoch 3 the training accuracy is 0.765
# epoch 3/20
# The test loss is 0.615770161151886
# The test accuracy is 0.782
# At epoch 4 the training loss is 0.46845337774604556
# At epoch 4 the training accuracy is 0.793
# epoch 4/20
# The test loss is 0.5838995575904846
# The test accuracy is 0.807
# At epoch 5 the training loss is 0.3914621280855499
# At epoch 5 the training accuracy is 0.824
# epoch 5/20
# The test loss is 0.5503456592559814
# The test accuracy is 0.805
# At epoch 6 the training loss is 0.3356478421483189
# At epoch 6 the training accuracy is 0.856
# epoch 6/20
# The test loss is 0.5377371311187744
# The test accuracy is 0.827
# At epoch 7 the training loss is 0.3027227972075343
# At epoch 7 the training accuracy is 0.868
# epoch 7/20
# The test loss is 0.5301001071929932
# The test accuracy is 0.835
# At epoch 8 the training loss is 0.2668284303601831
# At epoch 8 the training accuracy is 0.888
# epoch 8/20
# The test loss is 0.5198482275009155
# The test accuracy is 0.848
# At epoch 9 the training loss is 0.24126144306268543
# At epoch 9 the training accuracy is 0.893
# epoch 9/20
# The test loss is 0.5400187969207764
# The test accuracy is 0.835
# At epoch 10 the training loss is 0.23305573617108166
# At epoch 10 the training accuracy is 0.901
# epoch 10/20
# The test loss is 0.5500485897064209
# The test accuracy is 0.84
# At epoch 11 the training loss is 0.18529598090564833
# At epoch 11 the training accuracy is 0.926
# epoch 11/20
# The test loss is 0.5340628623962402
# The test accuracy is 0.847
# At epoch 12 the training loss is 0.17161896833917126
# At epoch 12 the training accuracy is 0.933
# epoch 12/20
# The test loss is 0.5248874425888062
# The test accuracy is 0.85
# At epoch 13 the training loss is 0.160010684087174
# At epoch 13 the training accuracy is 0.937
# epoch 13/20
# The test loss is 0.5379186868667603
# The test accuracy is 0.851
# At epoch 14 the training loss is 0.13100245205452665
# At epoch 14 the training accuracy is 0.946
# epoch 14/20
# The test loss is 0.5622597932815552
# The test accuracy is 0.853
# At epoch 15 the training loss is 0.13077791063347832
# At epoch 15 the training accuracy is 0.949
# epoch 15/20
# The test loss is 0.5473494529724121
# The test accuracy is 0.861
# At epoch 16 the training loss is 0.13768692489829845
# At epoch 16 the training accuracy is 0.934
# epoch 16/20
# The test loss is 0.5534263253211975
# The test accuracy is 0.858
# At epoch 17 the training loss is 0.10622224819409894
# At epoch 17 the training accuracy is 0.952
# epoch 17/20
# The test loss is 0.6060827970504761
# The test accuracy is 0.848
# At epoch 18 the training loss is 0.10786181870731525
# At epoch 18 the training accuracy is 0.959
# epoch 18/20
# The test loss is 0.5879762172698975
# The test accuracy is 0.858
# At epoch 19 the training loss is 0.1054172566102352
# At epoch 19 the training accuracy is 0.964
# epoch 19/20
# The test loss is 0.5652977824211121
# The test accuracy is 0.862
# At epoch 20 the training loss is 0.11044754017144441
# At epoch 20 the training accuracy is 0.956
# epoch 20/20
# The test loss is 0.586330771446228
# The test accuracy is 0.862
# The test loss is 0.5863307118415833
# The test accuracy is 0.862
# In epoch 20, on the test set we obtain a loss of 0.59 and an accuracy of 0.86
# Model for weight_sharing = True and aux loss = False on round 1 with subnet FCN
# At epoch 1 the training loss is 0.6983541475236416
# At epoch 1 the training accuracy is 0.664
# epoch 1/20
# The test loss is 0.5213655233383179
# The test accuracy is 0.745
# At epoch 2 the training loss is 0.48646071122959256
# At epoch 2 the training accuracy is 0.778
# epoch 2/20
# The test loss is 0.471280962228775
# The test accuracy is 0.777
# At epoch 3 the training loss is 0.3788010524492711
# At epoch 3 the training accuracy is 0.83
# epoch 3/20
# The test loss is 0.42827558517456055
# The test accuracy is 0.813
# At epoch 4 the training loss is 0.3016503427643329
# At epoch 4 the training accuracy is 0.867
# epoch 4/20
# The test loss is 0.42769068479537964
# The test accuracy is 0.819
# At epoch 5 the training loss is 0.29580309976241553
# At epoch 5 the training accuracy is 0.873
# epoch 5/20
# The test loss is 0.4212647080421448
# The test accuracy is 0.81
# At epoch 6 the training loss is 0.2681257047667168
# At epoch 6 the training accuracy is 0.902
# epoch 6/20
# The test loss is 0.3796811103820801
# The test accuracy is 0.831
# At epoch 7 the training loss is 0.20921686752699314
# At epoch 7 the training accuracy is 0.916
# epoch 7/20
# The test loss is 0.4369092583656311
# The test accuracy is 0.832
# At epoch 8 the training loss is 0.1985513755039028
# At epoch 8 the training accuracy is 0.927
# epoch 8/20
# The test loss is 0.44989871978759766
# The test accuracy is 0.826
# At epoch 9 the training loss is 0.15737158146890579
# At epoch 9 the training accuracy is 0.94
# epoch 9/20
# The test loss is 0.5396205186843872
# The test accuracy is 0.824
# At epoch 10 the training loss is 0.12435037701121474
# At epoch 10 the training accuracy is 0.955
# epoch 10/20
# The test loss is 0.5844852924346924
# The test accuracy is 0.828
# At epoch 11 the training loss is 0.11666203285756638
# At epoch 11 the training accuracy is 0.957
# epoch 11/20
# The test loss is 0.5189449191093445
# The test accuracy is 0.826
# At epoch 12 the training loss is 0.08884169773671602
# At epoch 12 the training accuracy is 0.971
# epoch 12/20
# The test loss is 0.5542317032814026
# The test accuracy is 0.826
# At epoch 13 the training loss is 0.09205913560519548
# At epoch 13 the training accuracy is 0.963
# epoch 13/20
# The test loss is 0.6146971583366394
# The test accuracy is 0.832
# At epoch 14 the training loss is 0.07126263068608069
# At epoch 14 the training accuracy is 0.97
# epoch 14/20
# The test loss is 0.6294691562652588
# The test accuracy is 0.831
# At epoch 15 the training loss is 0.05395947162089669
# At epoch 15 the training accuracy is 0.98
# epoch 15/20
# The test loss is 0.6963694095611572
# The test accuracy is 0.824
# At epoch 16 the training loss is 0.07215470535351955
# At epoch 16 the training accuracy is 0.972
# epoch 16/20
# The test loss is 0.7310826778411865
# The test accuracy is 0.817
# At epoch 17 the training loss is 0.08154894767903897
# At epoch 17 the training accuracy is 0.971
# epoch 17/20
# The test loss is 0.6702330112457275
# The test accuracy is 0.821
# At epoch 18 the training loss is 0.057019882377600195
# At epoch 18 the training accuracy is 0.979
# epoch 18/20
# The test loss is 0.6615605354309082
# The test accuracy is 0.833
# At epoch 19 the training loss is 0.04619333438964077
# At epoch 19 the training accuracy is 0.983
# epoch 19/20
# The test loss is 0.7258889675140381
# The test accuracy is 0.825
# At epoch 20 the training loss is 0.03953864349729997
# At epoch 20 the training accuracy is 0.987
# epoch 20/20
# The test loss is 0.7243123650550842
# The test accuracy is 0.826
# The test loss is 0.7243126034736633
# The test accuracy is 0.826
# In epoch 20, on the test set we obtain a loss of 0.72 and an accuracy of 0.83
# Model for weight_sharing = True and aux loss = True on round 1 with subnet FCN
# At epoch 1 the training loss is 2.0452853564918043
# At epoch 1 the training accuracy is 0.635
# epoch 1/20
# The test loss is 0.7117941379547119
# The test accuracy is 0.742
# At epoch 2 the training loss is 0.7140974137932062
# At epoch 2 the training accuracy is 0.721
# epoch 2/20
# The test loss is 0.5653049349784851
# The test accuracy is 0.762
# At epoch 3 the training loss is 0.516274518109858
# At epoch 3 the training accuracy is 0.801
# epoch 3/20
# The test loss is 0.48369675874710083
# The test accuracy is 0.81
# At epoch 4 the training loss is 0.4381121532805264
# At epoch 4 the training accuracy is 0.798
# epoch 4/20
# The test loss is 0.4489063024520874
# The test accuracy is 0.837
# At epoch 5 the training loss is 0.379739895183593
# At epoch 5 the training accuracy is 0.837
# epoch 5/20
# The test loss is 0.4029865264892578
# The test accuracy is 0.855
# At epoch 6 the training loss is 0.3309731275308877
# At epoch 6 the training accuracy is 0.853
# epoch 6/20
# The test loss is 0.445435106754303
# The test accuracy is 0.849
# At epoch 7 the training loss is 0.3036515793111175
# At epoch 7 the training accuracy is 0.873
# epoch 7/20
# The test loss is 0.3823690414428711
# The test accuracy is 0.866
# At epoch 8 the training loss is 0.26536184751428665
# At epoch 8 the training accuracy is 0.883
# epoch 8/20
# The test loss is 0.3795507252216339
# The test accuracy is 0.876
# At epoch 9 the training loss is 0.24462267246097327
# At epoch 9 the training accuracy is 0.895
# epoch 9/20
# The test loss is 0.3661603629589081
# The test accuracy is 0.876
# At epoch 10 the training loss is 0.2063966968236491
# At epoch 10 the training accuracy is 0.916
# epoch 10/20
# The test loss is 0.392005980014801
# The test accuracy is 0.876
# At epoch 11 the training loss is 0.21089148991391993
# At epoch 11 the training accuracy is 0.918
# epoch 11/20
# The test loss is 0.36990612745285034
# The test accuracy is 0.885
# At epoch 12 the training loss is 0.17754855639010203
# At epoch 12 the training accuracy is 0.93
# epoch 12/20
# The test loss is 0.3695468008518219
# The test accuracy is 0.892
# At epoch 13 the training loss is 0.18645610694977222
# At epoch 13 the training accuracy is 0.925
# epoch 13/20
# The test loss is 0.36079171299934387
# The test accuracy is 0.884
# At epoch 14 the training loss is 0.156699223597534
# At epoch 14 the training accuracy is 0.942
# epoch 14/20
# The test loss is 0.37337493896484375
# The test accuracy is 0.887
# At epoch 15 the training loss is 0.14676858575548976
# At epoch 15 the training accuracy is 0.943
# epoch 15/20
# The test loss is 0.38725608587265015
# The test accuracy is 0.884
# At epoch 16 the training loss is 0.1473322183988057
# At epoch 16 the training accuracy is 0.933
# epoch 16/20
# The test loss is 0.38483089208602905
# The test accuracy is 0.893
# At epoch 17 the training loss is 0.12833269681141246
# At epoch 17 the training accuracy is 0.952
# epoch 17/20
# The test loss is 0.37889060378074646
# The test accuracy is 0.89
# At epoch 18 the training loss is 0.13598900928220245
# At epoch 18 the training accuracy is 0.948
# epoch 18/20
# The test loss is 0.39565494656562805
# The test accuracy is 0.888
# At epoch 19 the training loss is 0.11764267799633671
# At epoch 19 the training accuracy is 0.958
# epoch 19/20
# The test loss is 0.3816307783126831
# The test accuracy is 0.897
# At epoch 20 the training loss is 0.10754521354683674
# At epoch 20 the training accuracy is 0.963
# epoch 20/20
# The test loss is 0.4025510549545288
# The test accuracy is 0.894
# The test loss is 0.40255090594291687
# The test accuracy is 0.894
# In epoch 20, on the test set we obtain a loss of 0.40 and an accuracy of 0.89
# Model for weight_sharing = False and aux loss = False on round 2 with subnet FCN
# At epoch 1 the training loss is 0.7756705888919533
# At epoch 1 the training accuracy is 0.648
# epoch 1/20
# The test loss is 0.5510685443878174
# The test accuracy is 0.715
# At epoch 2 the training loss is 0.4960364137031138
# At epoch 2 the training accuracy is 0.769
# epoch 2/20
# The test loss is 0.5344958305358887
# The test accuracy is 0.736
# At epoch 3 the training loss is 0.42492884466424585
# At epoch 3 the training accuracy is 0.809
# epoch 3/20
# The test loss is 0.4246656000614166
# The test accuracy is 0.786
# At epoch 4 the training loss is 0.3681642548600212
# At epoch 4 the training accuracy is 0.839
# epoch 4/20
# The test loss is 0.44676750898361206
# The test accuracy is 0.798
# At epoch 5 the training loss is 0.3158854807750322
# At epoch 5 the training accuracy is 0.862
# epoch 5/20
# The test loss is 0.44629666209220886
# The test accuracy is 0.786
# At epoch 6 the training loss is 0.2679390923096798
# At epoch 6 the training accuracy is 0.894
# epoch 6/20
# The test loss is 0.4569380581378937
# The test accuracy is 0.804
# At epoch 7 the training loss is 0.2242019470827654
# At epoch 7 the training accuracy is 0.916
# epoch 7/20
# The test loss is 0.5356094241142273
# The test accuracy is 0.79
# At epoch 8 the training loss is 0.18459159829973942
# At epoch 8 the training accuracy is 0.92
# epoch 8/20
# The test loss is 0.5486294031143188
# The test accuracy is 0.799
# At epoch 9 the training loss is 0.15631025768120935
# At epoch 9 the training accuracy is 0.933
# epoch 9/20
# The test loss is 0.5735763311386108
# The test accuracy is 0.806
# At epoch 10 the training loss is 0.11234809596586275
# At epoch 10 the training accuracy is 0.956
# epoch 10/20
# The test loss is 0.6321981549263
# The test accuracy is 0.812
# At epoch 11 the training loss is 0.07916060521015651
# At epoch 11 the training accuracy is 0.977
# epoch 11/20
# The test loss is 0.7616763710975647
# The test accuracy is 0.791
# At epoch 12 the training loss is 0.10135090166489476
# At epoch 12 the training accuracy is 0.963
# epoch 12/20
# The test loss is 0.6807488799095154
# The test accuracy is 0.798
# At epoch 13 the training loss is 0.08292120406117647
# At epoch 13 the training accuracy is 0.967
# epoch 13/20
# The test loss is 0.724229097366333
# The test accuracy is 0.811
# At epoch 14 the training loss is 0.05220641318184789
# At epoch 14 the training accuracy is 0.98
# epoch 14/20
# The test loss is 0.8192243576049805
# The test accuracy is 0.813
# At epoch 15 the training loss is 0.05400239403825026
# At epoch 15 the training accuracy is 0.984
# epoch 15/20
# The test loss is 0.8351110219955444
# The test accuracy is 0.81
# At epoch 16 the training loss is 0.05690792521829167
# At epoch 16 the training accuracy is 0.983
# epoch 16/20
# The test loss is 0.8156511187553406
# The test accuracy is 0.809
# At epoch 17 the training loss is 0.05583629042462178
# At epoch 17 the training accuracy is 0.978
# epoch 17/20
# The test loss is 0.8126871585845947
# The test accuracy is 0.816
# At epoch 18 the training loss is 0.026119630957123264
# At epoch 18 the training accuracy is 0.991
# epoch 18/20
# The test loss is 0.8854708075523376
# The test accuracy is 0.816
# At epoch 19 the training loss is 0.023005837721683804
# At epoch 19 the training accuracy is 0.992
# epoch 19/20
# The test loss is 1.0071464776992798
# The test accuracy is 0.814
# At epoch 20 the training loss is 0.02839425539774869
# At epoch 20 the training accuracy is 0.993
# epoch 20/20
# The test loss is 0.9857410788536072
# The test accuracy is 0.807
# The test loss is 0.9857414364814758
# The test accuracy is 0.807
# In epoch 20, on the test set we obtain a loss of 0.99 and an accuracy of 0.81
# Model for weight_sharing = False and aux loss = True on round 2 with subnet FCN
# At epoch 1 the training loss is 3.1564817041158677
# At epoch 1 the training accuracy is 0.637
# epoch 1/20
# The test loss is 0.8096649646759033
# The test accuracy is 0.778
# At epoch 2 the training loss is 0.7723476080596448
# At epoch 2 the training accuracy is 0.754
# epoch 2/20
# The test loss is 0.6692111492156982
# The test accuracy is 0.775
# At epoch 3 the training loss is 0.5699287724494934
# At epoch 3 the training accuracy is 0.79
# epoch 3/20
# The test loss is 0.5644828677177429
# The test accuracy is 0.81
# At epoch 4 the training loss is 0.4567224832996726
# At epoch 4 the training accuracy is 0.822
# epoch 4/20
# The test loss is 0.5961101651191711
# The test accuracy is 0.803
# At epoch 5 the training loss is 0.39627313283272086
# At epoch 5 the training accuracy is 0.863
# epoch 5/20
# The test loss is 0.5255451202392578
# The test accuracy is 0.829
# At epoch 6 the training loss is 0.35827567664906385
# At epoch 6 the training accuracy is 0.853
# epoch 6/20
# The test loss is 0.5009379386901855
# The test accuracy is 0.845
# At epoch 7 the training loss is 0.3190236548800021
# At epoch 7 the training accuracy is 0.866
# epoch 7/20
# The test loss is 0.5110652446746826
# The test accuracy is 0.841
# At epoch 8 the training loss is 0.27216014329344035
# At epoch 8 the training accuracy is 0.902
# epoch 8/20
# The test loss is 0.49643629789352417
# The test accuracy is 0.847
# At epoch 9 the training loss is 0.24310219798237084
# At epoch 9 the training accuracy is 0.907
# epoch 9/20
# The test loss is 0.5041477680206299
# The test accuracy is 0.85
# At epoch 10 the training loss is 0.21359971865662375
# At epoch 10 the training accuracy is 0.911
# epoch 10/20
# The test loss is 0.49033069610595703
# The test accuracy is 0.848
# At epoch 11 the training loss is 0.21679479066748172
# At epoch 11 the training accuracy is 0.918
# epoch 11/20
# The test loss is 0.4771459400653839
# The test accuracy is 0.854
# At epoch 12 the training loss is 0.1677280384907499
# At epoch 12 the training accuracy is 0.944
# epoch 12/20
# The test loss is 0.49842149019241333
# The test accuracy is 0.845
# At epoch 13 the training loss is 0.16715120649008897
# At epoch 13 the training accuracy is 0.934
# epoch 13/20
# The test loss is 0.4914039373397827
# The test accuracy is 0.849
# At epoch 14 the training loss is 0.16503793297102676
# At epoch 14 the training accuracy is 0.934
# epoch 14/20
# The test loss is 0.5076540112495422
# The test accuracy is 0.848
# At epoch 15 the training loss is 0.15484808595618232
# At epoch 15 the training accuracy is 0.936
# epoch 15/20
# The test loss is 0.4968302845954895
# The test accuracy is 0.85
# At epoch 16 the training loss is 0.14593807523953728
# At epoch 16 the training accuracy is 0.942
# epoch 16/20
# The test loss is 0.5442569255828857
# The test accuracy is 0.858
# At epoch 17 the training loss is 0.129368721897481
# At epoch 17 the training accuracy is 0.954
# epoch 17/20
# The test loss is 0.5428786277770996
# The test accuracy is 0.859
# At epoch 18 the training loss is 0.12992365542566403
# At epoch 18 the training accuracy is 0.957
# epoch 18/20
# The test loss is 0.5234689712524414
# The test accuracy is 0.864
# At epoch 19 the training loss is 0.10975463288283209
# At epoch 19 the training accuracy is 0.955
# epoch 19/20
# The test loss is 0.5239874124526978
# The test accuracy is 0.858
# At epoch 20 the training loss is 0.10676944349906989
# At epoch 20 the training accuracy is 0.961
# epoch 20/20
# The test loss is 0.5252730846405029
# The test accuracy is 0.863
# The test loss is 0.5252730846405029
# The test accuracy is 0.863
# In epoch 20, on the test set we obtain a loss of 0.53 and an accuracy of 0.86
# Model for weight_sharing = True and aux loss = False on round 2 with subnet FCN
# At epoch 1 the training loss is 0.7006318189576268
# At epoch 1 the training accuracy is 0.658
# epoch 1/20
# The test loss is 0.4869755208492279
# The test accuracy is 0.753
# At epoch 2 the training loss is 0.47363922506570816
# At epoch 2 the training accuracy is 0.768
# epoch 2/20
# The test loss is 0.4408280551433563
# The test accuracy is 0.776
# At epoch 3 the training loss is 0.39464958511292936
# At epoch 3 the training accuracy is 0.817
# epoch 3/20
# The test loss is 0.46481049060821533
# The test accuracy is 0.796
# At epoch 4 the training loss is 0.3683987156697549
# At epoch 4 the training accuracy is 0.853
# epoch 4/20
# The test loss is 0.41655221581459045
# The test accuracy is 0.814
# At epoch 5 the training loss is 0.3071189490146935
# At epoch 5 the training accuracy is 0.876
# epoch 5/20
# The test loss is 0.40808892250061035
# The test accuracy is 0.819
# At epoch 6 the training loss is 0.2687578403484076
# At epoch 6 the training accuracy is 0.883
# epoch 6/20
# The test loss is 0.4115431606769562
# The test accuracy is 0.838
# At epoch 7 the training loss is 0.2284348929906264
# At epoch 7 the training accuracy is 0.915
# epoch 7/20
# The test loss is 0.40091508626937866
# The test accuracy is 0.84
# At epoch 8 the training loss is 0.19220457005198113
# At epoch 8 the training accuracy is 0.923
# epoch 8/20
# The test loss is 0.44208282232284546
# The test accuracy is 0.835
# At epoch 9 the training loss is 0.18374024732031102
# At epoch 9 the training accuracy is 0.94
# epoch 9/20
# The test loss is 0.4985363781452179
# The test accuracy is 0.829
# At epoch 10 the training loss is 0.14664325773133896
# At epoch 10 the training accuracy is 0.945
# epoch 10/20
# The test loss is 0.47011205554008484
# The test accuracy is 0.846
# At epoch 11 the training loss is 0.12253630494233221
# At epoch 11 the training accuracy is 0.958
# epoch 11/20
# The test loss is 0.6081991791725159
# The test accuracy is 0.818
# At epoch 12 the training loss is 0.10993145282109708
# At epoch 12 the training accuracy is 0.965
# epoch 12/20
# The test loss is 0.5948017239570618
# The test accuracy is 0.841
# At epoch 13 the training loss is 0.0937107967774864
# At epoch 13 the training accuracy is 0.964
# epoch 13/20
# The test loss is 0.6225675940513611
# The test accuracy is 0.849
# At epoch 14 the training loss is 0.07233053625936918
# At epoch 14 the training accuracy is 0.97
# epoch 14/20
# The test loss is 0.6380247473716736
# The test accuracy is 0.847
# At epoch 15 the training loss is 0.06465321791514271
# At epoch 15 the training accuracy is 0.981
# epoch 15/20
# The test loss is 0.6730539202690125
# The test accuracy is 0.841
# At epoch 16 the training loss is 0.05114078280597709
# At epoch 16 the training accuracy is 0.977
# epoch 16/20
# The test loss is 0.6533843874931335
# The test accuracy is 0.851
# At epoch 17 the training loss is 0.05529233611634027
# At epoch 17 the training accuracy is 0.981
# epoch 17/20
# The test loss is 0.6895597577095032
# The test accuracy is 0.846
# At epoch 18 the training loss is 0.04759297202466087
# At epoch 18 the training accuracy is 0.984
# epoch 18/20
# The test loss is 0.7150919437408447
# The test accuracy is 0.848
# At epoch 19 the training loss is 0.04955872816957225
# At epoch 19 the training accuracy is 0.981
# epoch 19/20
# The test loss is 0.7133874893188477
# The test accuracy is 0.847
# At epoch 20 the training loss is 0.05204071729415318
# At epoch 20 the training accuracy is 0.983
# epoch 20/20
# The test loss is 0.6934643387794495
# The test accuracy is 0.847
# The test loss is 0.6934645771980286
# The test accuracy is 0.847
# In epoch 20, on the test set we obtain a loss of 0.69 and an accuracy of 0.85
# Model for weight_sharing = True and aux loss = True on round 2 with subnet FCN
# At epoch 1 the training loss is 2.112498443648219
# At epoch 1 the training accuracy is 0.683
# epoch 1/20
# The test loss is 0.6653503179550171
# The test accuracy is 0.762
# At epoch 2 the training loss is 0.7044726933166384
# At epoch 2 the training accuracy is 0.735
# epoch 2/20
# The test loss is 0.5721169114112854
# The test accuracy is 0.798
# At epoch 3 the training loss is 0.5476905922964215
# At epoch 3 the training accuracy is 0.794
# epoch 3/20
# The test loss is 0.4980928897857666
# The test accuracy is 0.83
# At epoch 4 the training loss is 0.4468860526010394
# At epoch 4 the training accuracy is 0.815
# epoch 4/20
# The test loss is 0.4811967611312866
# The test accuracy is 0.824
# At epoch 5 the training loss is 0.3857047457899898
# At epoch 5 the training accuracy is 0.838
# epoch 5/20
# The test loss is 0.432353675365448
# The test accuracy is 0.842
# At epoch 6 the training loss is 0.3271460610930808
# At epoch 6 the training accuracy is 0.861
# epoch 6/20
# The test loss is 0.40714898705482483
# The test accuracy is 0.839
# At epoch 7 the training loss is 0.29490968155674635
# At epoch 7 the training accuracy is 0.878
# epoch 7/20
# The test loss is 0.4209458529949188
# The test accuracy is 0.849
# At epoch 8 the training loss is 0.28684538301546125
# At epoch 8 the training accuracy is 0.875
# epoch 8/20
# The test loss is 0.40957316756248474
# The test accuracy is 0.85
# At epoch 9 the training loss is 0.22842287234030664
# At epoch 9 the training accuracy is 0.903
# epoch 9/20
# The test loss is 0.3939635157585144
# The test accuracy is 0.86
# At epoch 10 the training loss is 0.2201381651009433
# At epoch 10 the training accuracy is 0.901
# epoch 10/20
# The test loss is 0.41294577717781067
# The test accuracy is 0.85
# At epoch 11 the training loss is 0.1911830047436524
# At epoch 11 the training accuracy is 0.92
# epoch 11/20
# The test loss is 0.41136837005615234
# The test accuracy is 0.861
# At epoch 12 the training loss is 0.19023623025976122
# At epoch 12 the training accuracy is 0.928
# epoch 12/20
# The test loss is 0.4058113694190979
# The test accuracy is 0.878
# At epoch 13 the training loss is 0.1586607635789551
# At epoch 13 the training accuracy is 0.931
# epoch 13/20
# The test loss is 0.3986474573612213
# The test accuracy is 0.88
# At epoch 14 the training loss is 0.15422724080155603
# At epoch 14 the training accuracy is 0.937
# epoch 14/20
# The test loss is 0.3875548839569092
# The test accuracy is 0.869
# At epoch 15 the training loss is 0.14508993830066175
# At epoch 15 the training accuracy is 0.944
# epoch 15/20
# The test loss is 0.42006075382232666
# The test accuracy is 0.863
# At epoch 16 the training loss is 0.155163557510823
# At epoch 16 the training accuracy is 0.934
# epoch 16/20
# The test loss is 0.3927484452724457
# The test accuracy is 0.879
# At epoch 17 the training loss is 0.14435092350584455
# At epoch 17 the training accuracy is 0.941
# epoch 17/20
# The test loss is 0.39688199758529663
# The test accuracy is 0.882
# At epoch 18 the training loss is 0.12229308227426372
# At epoch 18 the training accuracy is 0.947
# epoch 18/20
# The test loss is 0.4059038460254669
# The test accuracy is 0.881
# At epoch 19 the training loss is 0.1235576132958522
# At epoch 19 the training accuracy is 0.954
# epoch 19/20
# The test loss is 0.3968326151371002
# The test accuracy is 0.886
# At epoch 20 the training loss is 0.11510011574835516
# At epoch 20 the training accuracy is 0.951
# epoch 20/20
# The test loss is 0.4187372326850891
# The test accuracy is 0.881
# The test loss is 0.4187374711036682
# The test accuracy is 0.881
# In epoch 20, on the test set we obtain a loss of 0.42 and an accuracy of 0.88
# Model for weight_sharing = False and aux loss = False on round 3 with subnet FCN
# At epoch 1 the training loss is 0.7672086272761226
# At epoch 1 the training accuracy is 0.611
# epoch 1/20
# The test loss is 0.5264898538589478
# The test accuracy is 0.742
# At epoch 2 the training loss is 0.5189238999411464
# At epoch 2 the training accuracy is 0.749
# epoch 2/20
# The test loss is 0.5810251832008362
# The test accuracy is 0.715
# At epoch 3 the training loss is 0.4084446586016566
# At epoch 3 the training accuracy is 0.801
# epoch 3/20
# The test loss is 0.4495849311351776
# The test accuracy is 0.801
# At epoch 4 the training loss is 0.35698521871003325
# At epoch 4 the training accuracy is 0.833
# epoch 4/20
# The test loss is 0.43066713213920593
# The test accuracy is 0.793
# At epoch 5 the training loss is 0.3143912789202295
# At epoch 5 the training accuracy is 0.862
# epoch 5/20
# The test loss is 0.43994730710983276
# The test accuracy is 0.812
# At epoch 6 the training loss is 0.2471510187839158
# At epoch 6 the training accuracy is 0.899
# epoch 6/20
# The test loss is 0.45755934715270996
# The test accuracy is 0.8
# At epoch 7 the training loss is 0.2560529600281734
# At epoch 7 the training accuracy is 0.899
# epoch 7/20
# The test loss is 0.41541191935539246
# The test accuracy is 0.823
# At epoch 8 the training loss is 0.18584912885831728
# At epoch 8 the training accuracy is 0.934
# epoch 8/20
# The test loss is 0.49868300557136536
# The test accuracy is 0.818
# At epoch 9 the training loss is 0.1532053784636446
# At epoch 9 the training accuracy is 0.939
# epoch 9/20
# The test loss is 0.5455473065376282
# The test accuracy is 0.814
# At epoch 10 the training loss is 0.1372233409961302
# At epoch 10 the training accuracy is 0.945
# epoch 10/20
# The test loss is 0.5586142539978027
# The test accuracy is 0.812
# At epoch 11 the training loss is 0.11885325899578994
# At epoch 11 the training accuracy is 0.953
# epoch 11/20
# The test loss is 0.619963526725769
# The test accuracy is 0.807
# At epoch 12 the training loss is 0.08213395454913552
# At epoch 12 the training accuracy is 0.97
# epoch 12/20
# The test loss is 0.8024675250053406
# The test accuracy is 0.813
# At epoch 13 the training loss is 0.0753393369619137
# At epoch 13 the training accuracy is 0.976
# epoch 13/20
# The test loss is 0.7474629878997803
# The test accuracy is 0.819
# At epoch 14 the training loss is 0.06849266289476987
# At epoch 14 the training accuracy is 0.97
# epoch 14/20
# The test loss is 0.7692295908927917
# The test accuracy is 0.809
# At epoch 15 the training loss is 0.0632618362399603
# At epoch 15 the training accuracy is 0.979
# epoch 15/20
# The test loss is 0.7154453992843628
# The test accuracy is 0.822
# At epoch 16 the training loss is 0.04130268375166111
# At epoch 16 the training accuracy is 0.985
# epoch 16/20
# The test loss is 0.7920248508453369
# The test accuracy is 0.824
# At epoch 17 the training loss is 0.03374427282315309
# At epoch 17 the training accuracy is 0.986
# epoch 17/20
# The test loss is 0.8279910683631897
# The test accuracy is 0.816
# At epoch 18 the training loss is 0.029098277666292915
# At epoch 18 the training accuracy is 0.988
# epoch 18/20
# The test loss is 0.86865234375
# The test accuracy is 0.821
# At epoch 19 the training loss is 0.04014397161388303
# At epoch 19 the training accuracy is 0.986
# epoch 19/20
# The test loss is 0.8640676140785217
# The test accuracy is 0.821
# At epoch 20 the training loss is 0.02233889053164873
# At epoch 20 the training accuracy is 0.991
# epoch 20/20
# The test loss is 0.9170873165130615
# The test accuracy is 0.816
# The test loss is 0.9170880317687988
# The test accuracy is 0.816
# In epoch 20, on the test set we obtain a loss of 0.92 and an accuracy of 0.82
# Model for weight_sharing = False and aux loss = True on round 3 with subnet FCN
# At epoch 1 the training loss is 3.0050810919702053
# At epoch 1 the training accuracy is 0.612
# epoch 1/20
# The test loss is 0.959007740020752
# The test accuracy is 0.683
# At epoch 2 the training loss is 0.8131071681529284
# At epoch 2 the training accuracy is 0.723
# epoch 2/20
# The test loss is 0.7738942503929138
# The test accuracy is 0.727
# At epoch 3 the training loss is 0.5758183930814266
# At epoch 3 the training accuracy is 0.769
# epoch 3/20
# The test loss is 0.6126818060874939
# The test accuracy is 0.761
# At epoch 4 the training loss is 0.48250491797924044
# At epoch 4 the training accuracy is 0.785
# epoch 4/20
# The test loss is 0.5968528389930725
# The test accuracy is 0.78
# At epoch 5 the training loss is 0.4202397294715047
# At epoch 5 the training accuracy is 0.807
# epoch 5/20
# The test loss is 0.5758209228515625
# The test accuracy is 0.799
# At epoch 6 the training loss is 0.34327740492299197
# At epoch 6 the training accuracy is 0.849
# epoch 6/20
# The test loss is 0.5365650653839111
# The test accuracy is 0.826
# At epoch 7 the training loss is 0.29143256390467287
# ...
# The test loss is 0.36363333463668823
# The test accuracy is 0.878
# At epoch 13 the training loss is 0.16757534937467425
# At epoch 13 the training accuracy is 0.928
# epoch 13/20
# The test loss is 0.35661613941192627
# The test accuracy is 0.883
# At epoch 14 the training loss is 0.16124409017153085
# At epoch 14 the training accuracy is 0.932
# epoch 14/20
# The test loss is 0.35749420523643494
# The test accuracy is 0.892
# At epoch 15 the training loss is 0.13855229559354484
# At epoch 15 the training accuracy is 0.949
# epoch 15/20
# The test loss is 0.3482089936733246
# The test accuracy is 0.896
# At epoch 16 the training loss is 0.12618747402913869
# At epoch 16 the training accuracy is 0.961
# epoch 16/20
# The test loss is 0.34867340326309204
# The test accuracy is 0.893
# At epoch 17 the training loss is 0.12508500243988238
# At epoch 17 the training accuracy is 0.944
# epoch 17/20
# The test loss is 0.3722071647644043
# The test accuracy is 0.883
# At epoch 18 the training loss is 0.11458580846257974
# At epoch 18 the training accuracy is 0.955
# epoch 18/20
# The test loss is 0.3765360713005066
# The test accuracy is 0.891
# At epoch 19 the training loss is 0.10806563971331343
# At epoch 19 the training accuracy is 0.971
# epoch 19/20
# The test loss is 0.38243603706359863
# The test accuracy is 0.887
# At epoch 20 the training loss is 0.10084563331183745
# At epoch 20 the training accuracy is 0.967
# epoch 20/20
# The test loss is 0.3846592307090759
# The test accuracy is 0.892
# The test loss is 0.38465917110443115
# The test accuracy is 0.892
# In epoch 20, on the test set we obtain a loss of 0.38 and an accuracy of 0.89
# Model for weight_sharing = False and aux loss = False on round 9 with subnet FCN
# At epoch 1 the training loss is 0.749464514479041
# At epoch 1 the training accuracy is 0.633
# epoch 1/20
# The test loss is 0.5008983612060547
# The test accuracy is 0.738
# At epoch 2 the training loss is 0.5253309426270425
# At epoch 2 the training accuracy is 0.746
# epoch 2/20
# The test loss is 0.4379795491695404
# The test accuracy is 0.795
# At epoch 3 the training loss is 0.4173458389379084
# At epoch 3 the training accuracy is 0.813
# epoch 3/20
# The test loss is 0.43165355920791626
# The test accuracy is 0.79
# At epoch 4 the training loss is 0.3604708412755281
# At epoch 4 the training accuracy is 0.846
# epoch 4/20
# The test loss is 0.4566870629787445
# The test accuracy is 0.805
# At epoch 5 the training loss is 0.3131174781778827
# At epoch 5 the training accuracy is 0.863
# epoch 5/20
# The test loss is 0.46172723174095154
# The test accuracy is 0.802
# At epoch 6 the training loss is 0.28691372406668963
# At epoch 6 the training accuracy is 0.874
# epoch 6/20
# The test loss is 0.4430287480354309
# The test accuracy is 0.803
# At epoch 7 the training loss is 0.2310881418545614
# At epoch 7 the training accuracy is 0.902
# epoch 7/20
# The test loss is 0.4815419018268585
# The test accuracy is 0.806
# At epoch 8 the training loss is 0.18099048261530698
# At epoch 8 the training accuracy is 0.929
# epoch 8/20
# The test loss is 0.5210887789726257
# The test accuracy is 0.824
# At epoch 9 the training loss is 0.12651328899846703
# At epoch 9 the training accuracy is 0.957
# epoch 9/20
# The test loss is 0.5601613521575928
# The test accuracy is 0.826
# At epoch 10 the training loss is 0.12291067522317461
# At epoch 10 the training accuracy is 0.952
# epoch 10/20
# The test loss is 0.6154327392578125
# The test accuracy is 0.811
# At epoch 11 the training loss is 0.11356401577399083
# At epoch 11 the training accuracy is 0.956
# epoch 11/20
# The test loss is 0.6454227566719055
# The test accuracy is 0.795
# At epoch 12 the training loss is 0.08677722880188413
# At epoch 12 the training accuracy is 0.969
# epoch 12/20
# The test loss is 0.71720290184021
# The test accuracy is 0.813
# At epoch 13 the training loss is 0.090880171927638
# At epoch 13 the training accuracy is 0.972
# epoch 13/20
# The test loss is 0.7442256808280945
# The test accuracy is 0.808
# At epoch 14 the training loss is 0.0697173144876433
# At epoch 14 the training accuracy is 0.975
# epoch 14/20
# The test loss is 0.702200174331665
# The test accuracy is 0.808
# At epoch 15 the training loss is 0.05534719726071899
# At epoch 15 the training accuracy is 0.978
# epoch 15/20
# The test loss is 0.752673327922821
# The test accuracy is 0.822
# At epoch 16 the training loss is 0.04985593621795133
# At epoch 16 the training accuracy is 0.98
# epoch 16/20
# The test loss is 0.7009232044219971
# The test accuracy is 0.821
# At epoch 17 the training loss is 0.053311596347189155
# At epoch 17 the training accuracy is 0.975
# epoch 17/20
# The test loss is 0.7617477178573608
# The test accuracy is 0.809
# At epoch 18 the training loss is 0.03289922852460677
# At epoch 18 the training accuracy is 0.985
# epoch 18/20
# The test loss is 0.7973676919937134
# The test accuracy is 0.815
# At epoch 19 the training loss is 0.07040736929956892
# At epoch 19 the training accuracy is 0.979
# epoch 19/20
# The test loss is 0.7704278826713562
# The test accuracy is 0.82
# At epoch 20 the training loss is 0.036302767060803945
# At epoch 20 the training accuracy is 0.989
# epoch 20/20
# The test loss is 0.8030861020088196
# The test accuracy is 0.816
# The test loss is 0.8030862212181091
# The test accuracy is 0.816
# In epoch 20, on the test set we obtain a loss of 0.80 and an accuracy of 0.82
# Model for weight_sharing = False and aux loss = True on round 9 with subnet FCN
# At epoch 1 the training loss is 2.8807624074816705
# At epoch 1 the training accuracy is 0.618
# epoch 1/20
# The test loss is 0.886794924736023
# The test accuracy is 0.731
# At epoch 2 the training loss is 0.87027658008039
# At epoch 2 the training accuracy is 0.733
# epoch 2/20
# The test loss is 0.6593232154846191
# The test accuracy is 0.771
# At epoch 3 the training loss is 0.5947994062304497
# At epoch 3 the training accuracy is 0.746
# epoch 3/20
# The test loss is 0.6369041204452515
# The test accuracy is 0.784
# At epoch 4 the training loss is 0.4848069619759917
# At epoch 4 the training accuracy is 0.786
# epoch 4/20
# The test loss is 0.5734083652496338
# The test accuracy is 0.818
# At epoch 5 the training loss is 0.40736606389284136
# At epoch 5 the training accuracy is 0.822
# epoch 5/20
# The test loss is 0.5701465606689453
# The test accuracy is 0.837
# At epoch 6 the training loss is 0.3617627510614693
# At epoch 6 the training accuracy is 0.853
# epoch 6/20
# The test loss is 0.5244485139846802
# The test accuracy is 0.851
# At epoch 7 the training loss is 0.3165856363810599
# At epoch 7 the training accuracy is 0.864
# epoch 7/20
# The test loss is 0.5400841236114502
# The test accuracy is 0.836
# At epoch 8 the training loss is 0.28282908365130427
# At epoch 8 the training accuracy is 0.879
# epoch 8/20
# The test loss is 0.4948917031288147
# The test accuracy is 0.863
# At epoch 9 the training loss is 0.234711541919969
# At epoch 9 the training accuracy is 0.888
# epoch 9/20
# The test loss is 0.5751863121986389
# The test accuracy is 0.831
# At epoch 10 the training loss is 0.2246986570674926
# At epoch 10 the training accuracy is 0.897
# epoch 10/20
# The test loss is 0.5096771121025085
# The test accuracy is 0.855
# At epoch 11 the training loss is 0.1865551930712536
# At epoch 11 the training accuracy is 0.909
# epoch 11/20
# The test loss is 0.5084435939788818
# The test accuracy is 0.869
# At epoch 12 the training loss is 0.1673139009415172
# At epoch 12 the training accuracy is 0.931
# epoch 12/20
# The test loss is 0.4944007992744446
# The test accuracy is 0.88
# At epoch 13 the training loss is 0.16233598923077808
# At epoch 13 the training accuracy is 0.924
# epoch 13/20
# The test loss is 0.49071478843688965
# The test accuracy is 0.874
# At epoch 14 the training loss is 0.15552109078969806
# At epoch 14 the training accuracy is 0.93
# epoch 14/20
# The test loss is 0.545573353767395
# The test accuracy is 0.866
# At epoch 15 the training loss is 0.16616532136278692
# At epoch 15 the training accuracy is 0.94
# epoch 15/20
# The test loss is 0.48958706855773926
# The test accuracy is 0.874
# At epoch 16 the training loss is 0.13304808487067932
# At epoch 16 the training accuracy is 0.953
# epoch 16/20
# The test loss is 0.5003045201301575
# The test accuracy is 0.884
# At epoch 17 the training loss is 0.12062097717367579
# At epoch 17 the training accuracy is 0.946
# epoch 17/20
# The test loss is 0.5010418891906738
# The test accuracy is 0.881
# At epoch 18 the training loss is 0.1192352140447474
# At epoch 18 the training accuracy is 0.959
# epoch 18/20
# The test loss is 0.5404548645019531
# The test accuracy is 0.876
# At epoch 19 the training loss is 0.09773605642956681
# At epoch 19 the training accuracy is 0.969
# epoch 19/20
# The test loss is 0.5217677354812622
# The test accuracy is 0.886
# At epoch 20 the training loss is 0.10138571700634202
# At epoch 20 the training accuracy is 0.962
# epoch 20/20
# The test loss is 0.5478721857070923
# The test accuracy is 0.871
# The test loss is 0.5478719472885132
# The test accuracy is 0.871
# In epoch 20, on the test set we obtain a loss of 0.55 and an accuracy of 0.87
# Model for weight_sharing = True and aux loss = False on round 9 with subnet FCN
# At epoch 1 the training loss is 0.650282217413187
# At epoch 1 the training accuracy is 0.676
# epoch 1/20
# The test loss is 0.49076056480407715
# The test accuracy is 0.767
# At epoch 2 the training loss is 0.49729824520647525
# At epoch 2 the training accuracy is 0.774
# epoch 2/20
# The test loss is 0.4382253885269165
# The test accuracy is 0.798
# At epoch 3 the training loss is 0.3861777311563492
# At epoch 3 the training accuracy is 0.829
# epoch 3/20
# The test loss is 0.43676066398620605
# The test accuracy is 0.798
# At epoch 4 the training loss is 0.3510043964721262
# At epoch 4 the training accuracy is 0.845
# epoch 4/20
# The test loss is 0.40041860938072205
# The test accuracy is 0.825
# At epoch 5 the training loss is 0.29956963159609584
# At epoch 5 the training accuracy is 0.871
# epoch 5/20
# The test loss is 0.44118139147758484
# The test accuracy is 0.826
# At epoch 6 the training loss is 0.29013890933943914
# At epoch 6 the training accuracy is 0.877
# epoch 6/20
# The test loss is 0.39181485772132874
# The test accuracy is 0.839
# At epoch 7 the training loss is 0.24217804052634165
# At epoch 7 the training accuracy is 0.891
# epoch 7/20
# The test loss is 0.4221789538860321
# The test accuracy is 0.832
# At epoch 8 the training loss is 0.20485507567238528
# At epoch 8 the training accuracy is 0.931
# epoch 8/20
# The test loss is 0.41335421800613403
# The test accuracy is 0.844
# At epoch 9 the training loss is 0.17853011755927584
# At epoch 9 the training accuracy is 0.936
# epoch 9/20
# The test loss is 0.45426151156425476
# The test accuracy is 0.828
# At epoch 10 the training loss is 0.14578049852374533
# At epoch 10 the training accuracy is 0.942
# epoch 10/20
# The test loss is 0.47079920768737793
# The test accuracy is 0.831
# At epoch 11 the training loss is 0.12196486565517262
# At epoch 11 the training accuracy is 0.947
# epoch 11/20
# The test loss is 0.5505989789962769
# The test accuracy is 0.835
# At epoch 12 the training loss is 0.11353144854841048
# At epoch 12 the training accuracy is 0.959
# epoch 12/20
# The test loss is 0.5627799034118652
# The test accuracy is 0.83
# At epoch 13 the training loss is 0.09279468334883859
# At epoch 13 the training accuracy is 0.972
# epoch 13/20
# The test loss is 0.5541179180145264
# The test accuracy is 0.841
# At epoch 14 the training loss is 0.061364061838248746
# At epoch 14 the training accuracy is 0.976
# epoch 14/20
# The test loss is 0.6252681612968445
# The test accuracy is 0.839
# At epoch 15 the training loss is 0.08687152836056157
# At epoch 15 the training accuracy is 0.967
# epoch 15/20
# The test loss is 0.6217103004455566
# The test accuracy is 0.825
# At epoch 16 the training loss is 0.08698930899533934
# At epoch 16 the training accuracy is 0.969
# epoch 16/20
# The test loss is 0.6093807220458984
# The test accuracy is 0.836
# At epoch 17 the training loss is 0.05649572556658256
# At epoch 17 the training accuracy is 0.984
# epoch 17/20
# The test loss is 0.6523594260215759
# The test accuracy is 0.833
# At epoch 18 the training loss is 0.05541416441372348
# At epoch 18 the training accuracy is 0.983
# epoch 18/20
# The test loss is 0.7148349285125732
# The test accuracy is 0.826
# At epoch 19 the training loss is 0.05698265785235037
# At epoch 19 the training accuracy is 0.983
# epoch 19/20
# The test loss is 0.7025703191757202
# The test accuracy is 0.832
# At epoch 20 the training loss is 0.05025427987753119
# At epoch 20 the training accuracy is 0.98
# epoch 20/20
# The test loss is 0.7080746293067932
# The test accuracy is 0.831
# The test loss is 0.7080745697021484
# The test accuracy is 0.831
# In epoch 20, on the test set we obtain a loss of 0.71 and an accuracy of 0.83
# Model for weight_sharing = True and aux loss = True on round 9 with subnet FCN
# At epoch 1 the training loss is 2.609094800204039
# At epoch 1 the training accuracy is 0.666
# epoch 1/20
# The test loss is 0.7539970874786377
# The test accuracy is 0.767
# At epoch 2 the training loss is 0.6907820031791926
# At epoch 2 the training accuracy is 0.771
# epoch 2/20
# The test loss is 0.5519547462463379
# The test accuracy is 0.784
# At epoch 3 the training loss is 0.5175981609709561
# At epoch 3 the training accuracy is 0.804
# epoch 3/20
# The test loss is 0.5150868892669678
# The test accuracy is 0.813
# At epoch 4 the training loss is 0.4110354732535779
# At epoch 4 the training accuracy is 0.844
# epoch 4/20
# The test loss is 0.4712383449077606
# The test accuracy is 0.832
# At epoch 5 the training loss is 0.3637197336181998
# At epoch 5 the training accuracy is 0.858
# epoch 5/20
# The test loss is 0.4697377681732178
# The test accuracy is 0.82
# At epoch 6 the training loss is 0.30968175306916235
# At epoch 6 the training accuracy is 0.869
# epoch 6/20
# The test loss is 0.4268493056297302
# The test accuracy is 0.847
# At epoch 7 the training loss is 0.28258266892749817
# At epoch 7 the training accuracy is 0.882
# epoch 7/20
# The test loss is 0.45540010929107666
# The test accuracy is 0.846
# At epoch 8 the training loss is 0.2351251313323155
# At epoch 8 the training accuracy is 0.904
# epoch 8/20
# The test loss is 0.4353603720664978
# The test accuracy is 0.853
# At epoch 9 the training loss is 0.2232134708436206
# At epoch 9 the training accuracy is 0.93
# epoch 9/20
# The test loss is 0.42146432399749756
# The test accuracy is 0.864
# At epoch 10 the training loss is 0.2004011193290353
# At epoch 10 the training accuracy is 0.928
# epoch 10/20
# The test loss is 0.4351617991924286
# The test accuracy is 0.863
# At epoch 11 the training loss is 0.18947479042690246
# At epoch 11 the training accuracy is 0.929
# epoch 11/20
# The test loss is 0.4379533529281616
# The test accuracy is 0.861
# At epoch 12 the training loss is 0.16802175564691424
# At epoch 12 the training accuracy is 0.933
# epoch 12/20
# The test loss is 0.4405268430709839
# The test accuracy is 0.865
# At epoch 13 the training loss is 0.1719891349808313
# At epoch 13 the training accuracy is 0.939
# epoch 13/20
# The test loss is 0.4391518235206604
# The test accuracy is 0.862
# At epoch 14 the training loss is 0.14996744990581645
# At epoch 14 the training accuracy is 0.948
# epoch 14/20
# The test loss is 0.4394102096557617
# The test accuracy is 0.862
# At epoch 15 the training loss is 0.13546560178743675
# At epoch 15 the training accuracy is 0.949
# epoch 15/20
# The test loss is 0.4203377962112427
# The test accuracy is 0.862
# At epoch 16 the training loss is 0.12235529536381363
# At epoch 16 the training accuracy is 0.958
# epoch 16/20
# The test loss is 0.48803001642227173
# The test accuracy is 0.859
# At epoch 17 the training loss is 0.13561848445970098
# At epoch 17 the training accuracy is 0.953
# epoch 17/20
# The test loss is 0.4696662425994873
# The test accuracy is 0.862
# At epoch 18 the training loss is 0.13554259825265036
# At epoch 18 the training accuracy is 0.958
# epoch 18/20
# The test loss is 0.4358995854854584
# The test accuracy is 0.87
# At epoch 19 the training loss is 0.1298344027949497
# At epoch 19 the training accuracy is 0.96
# epoch 19/20
# The test loss is 0.4625761806964874
# The test accuracy is 0.862
# At epoch 20 the training loss is 0.11159483108378482
# At epoch 20 the training accuracy is 0.967
# epoch 20/20
# The test loss is 0.44784170389175415
# The test accuracy is 0.87
# The test loss is 0.447841614484787
# The test accuracy is 0.87
# In epoch 20, on the test set we obtain a loss of 0.45 and an accuracy of 0.87

# %%
plots_results(round_results_FCN,'FCN')

# %%
means_FCN = np.array(round_results_FCN).mean(axis= 0)
means_FCN[:,3,19] #test_accuracy
# Out:
# array([0.8112, 0.8621, 0.8329, 0.8872])

# %%
std_FCN = np.array(round_results_FCN).std(axis= 0)
std_FCN[:,3,19] #test_accuracy
# Out:
# array([0.0069685 , 0.00884816, 0.00821523, 0.00716659])

# %% [markdown]
# #### Best FCN

# %%
round_results_best_FCN = compute_results_fcn('FCN', nb_hidden_layers = config.FCN_BEST_NB, 
                                             hidden_layer = config.FCN_BEST_HIDDEN,
                                             nb_hidden_layers_out = config.SIAMESE_NET_BEST_NB_FCN, 
                                             hidden_layer_out = config.SIAMESE_NET_BEST_HIDDEN_FCN, 
                                             alpha = config.BEST_ALPHA_FCN)
# Out:
# Model for weight_sharing = False and aux loss = False on round 0 with subnet FCN
# In epoch 20, on the test set we obtain a loss of 0.99 and an accuracy of 0.83
# Model for weight_sharing = False and aux loss = True on round 0 with subnet FCN
# In epoch 20, on the test set we obtain a loss of 0.51 and an accuracy of 0.91
# Model for weight_sharing = True and aux loss = False on round 0 with subnet FCN
# In epoch 20, on the test set we obtain a loss of 0.55 and an accuracy of 0.87
# Model for weight_sharing = True and aux loss = True on round 0 with subnet FCN
# In epoch 20, on the test set we obtain a loss of 0.34 and an accuracy of 0.93
# Model for weight_sharing = False and aux loss = False on round 1 with subnet FCN
# In epoch 20, on the test set we obtain a loss of 1.12 and an accuracy of 0.82
# Model for weight_sharing = False and aux loss = True on round 1 with subnet FCN
# In epoch 20, on the test set we obtain a loss of 0.43 and an accuracy of 0.90
# Model for weight_sharing = True and aux loss = False on round 1 with subnet FCN
# In epoch 20, on the test set we obtain a loss of 0.65 and an accuracy of 0.87
# Model for weight_sharing = True and aux loss = True on round 1 with subnet FCN
# In epoch 20, on the test set we obtain a loss of 0.34 and an accuracy of 0.93
# Model for weight_sharing = False and aux loss = False on round 2 with subnet FCN
# In epoch 20, on the test set we obtain a loss of 0.84 and an accuracy of 0.84
# Model for weight_sharing = False and aux loss = True on round 2 with subnet FCN
# In epoch 20, on the test set we obtain a loss of 0.50 and an accuracy of 0.90
# Model for weight_sharing = True and aux loss = False on round 2 with subnet FCN

# %%
means_best_FCN = np.array(round_results_best_FCN).mean(axis= 0)
means_best_FCN[:,3,19] #test_accuracy

# %%
std_best_FCN = np.array(round_results_best_FCN).std(axis= 0)
std_best_FCN[:,3,19] #test_accuracy

# %% [markdown]
# #### Subnet : CNN

# %%
CNN()

# %%
round_results_CNN = compute_results_cnn('CNN')

# %%
plots_results(round_results_CNN, 'CNN')

# %%
means_CNN = np.array(round_results_CNN).mean(axis= 0)
means_CNN[:,3,19] #test_accuracy

# %%
std_CNN = np.array(round_results_CNN).std(axis= 0)
std_CNN[:,3,19] #test_accuracy

# %% [markdown]
# #### Best CNN

# %%
round_results_best_CNN = compute_results_cnn('CNN', nb_hidden_layers = config.CNN_BEST_NB, 
                                            base_channel_size = config.CNN_BEST_CHANNEL, 
                                            hidden_layer = config.CNN_BEST_HIDDEN,
                                            kernel_size = config.CNN_BEST_KERNEL_SIZE,
                                            nb_hidden_layers_out = config.SIAMESE_NET_BEST_NB_CNN,
                                            hidden_layer_out = config.SIAMESE_NET_BEST_HIDDEN_CNN,
                                            alpha = config.BEST_ALPHA_CNN)

# %%
plots_results(round_results_best_CNN, 'CNN')

# %%
means_best_CNN = np.array(round_results_best_CNN).mean(axis= 0)
means_best_CNN[:,3,19] #test_accuracy

# %%
std_best_CNN = np.array(round_results_best_CNN).std(axis= 0)
std_best_CNN[:,3,19] #test_accuracy
